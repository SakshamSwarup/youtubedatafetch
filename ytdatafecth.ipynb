# %%
from googleapiclient.discovery import build

# %%
api_key = 'AIzaSyBQjea9k-IUbgNdJzIZ7-B9BvhUhFhut-Y'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id="UCM-yUTYGmrNvKOCcAl21g3w"
    )

# %%
response = request.execute()

# %%
channel_title = response['items'][0]['snippet']['title']

# %%
channel_description = response['items'][0]['snippet']['description']

# %%
channel_pub = response['items'][0]['snippet']['publishedAt']

# %%
channel_sub = response['items'][0]['statistics']['subscriberCount']

# %%
channel_vidCount=response['items'][0]['statistics']['videoCount']

# %%
channel_viewcount= response['items'][0]['statistics']['viewCount']

# %%
data = {
    "channel_title":channel_title,
    "channel_description": channel_description,
    "channel_pub": channel_pub,
    "channel_sub": channel_sub,
    "channel_vidCount": channel_vidCount,
    "channel_viewcount": channel_viewcount
    }

# %%
data
# Out:
# {'channel_title': "Jenny's Lectures CS IT",
#  'channel_description': "Warm Welcome to Jenny's Lectures. On This Channel we are focusing on creating tutorials for  engineers, software developers, programmers, Coders, undergraduates, graduates. We cover topics for all different skill levels, so whether you are a beginner or have some years of experience, this channel will have something for you.\n\nWe've already uploaded a wide variety of videos on topics that include: C, C++, Python, Computer Science Fundamentals, Computer Science subjects like OS, DBMS, Data Structures, DSA, DAA, Placement Series, GATE Coaching Videos, UGC NET syllabus Videos and plenty of other tips and tricks which will help you in your career.\n\n",
#  'channel_pub': '2019-01-19T18:46:22Z',
#  'channel_sub': '1450000',
#  'channel_vidCount': '689',
#  'channel_viewcount': '162527266'}

# %%
request_video = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id="Ks-_Mh1QhMc"
    )

# %%
response_vid = request_video.execute()

# %%
video_data = {
    "video_title":response_vid['items'][0]['snippet']['title'],
    "video_channelId": response_vid['items'][0]['snippet']['channelId'],
    "video_description": response_vid['items'][0]['snippet']['description'],
    "video_likecount": response_vid['items'][0]['statistics']['likeCount'],
    "video_tags": response_vid['items'][0]['snippet']['tags'],
    "video_commentCount": response_vid['items'][0]['statistics']['commentCount']
    }

# %%
video_data
# Out:
# {'video_title': 'Your body language may shape who you are | Amy Cuddy',
#  'video_channelId': 'UCAuUUnT6oDeKwE6v1NGQxug',
# ...

# %%
request_comment = youtube.commentThreads().list(
        part="snippet,replies",
        videoId="Ks-_Mh1QhMc"
    )

# %%
response_comment = request_comment.execute()

# %%
response_comment
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'nWbwqqzOZNmJ2btx3g8-iSf4x5A',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJY2dHQUFTQlFpSklCZ0FFZ1VJblNBWUFSSUZDSWdnR0FBWUFDSU9DZ3dJM2VyUHFRWVEtTFRvMVFN',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'Pzt3gGdDvuNvqj9qJUuODDrEfoo',
#    'id': 'UgyBr5THxBuQQHvfbpt4AaABAg',
#    'snippet': {'channelId': 'UCAuUUnT6oDeKwE6v1NGQxug',
#     'videoId': 'Ks-_Mh1QhMc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'PVvrBnbveEXvCu1WNxXNcRLVAT4',
#      'id': 'UgyBr5THxBuQQHvfbpt4AaABAg',
#      'snippet': {'channelId': 'UCAuUUnT6oDeKwE6v1NGQxug',
#       'videoId': 'Ks-_Mh1QhMc',
# ...

# %%
# Fetching all the Topcomments.
comment_data = {
    idx: item['snippet']['topLevelComment']['snippet']['textDisplay']
    for idx, item in enumerate(response_comment.get('items', []))
}

# %%
allcomments = {
"VideosID":response_comment['items'][0]['snippet']['topLevelComment']['snippet']['videoId'],
"AllComments":comment_data
}

# %%
allcomments
# Out:
# {'VideosID': 'Ks-_Mh1QhMc',
#  'AllComments': {0: 'Enjoying this talk? You&#39;ll love the brand new TED Radio Hour series – Mind, Body, Spirit. Hear TED speakers share their eye-opening ideas on how we think, move, and feel.\xa0https://www.youtube.com/playlist?list=PL2TjQf2riraLkqqFGxK65JI-leCAxm1eD',
#   1: 'One of the best talk I had listened to. Really amazing. Thanks Amy.',
#   2: 'She need to drink some water',
#   3: 'Thank you! It’s impressing! ‘Fake it till you become it’ ❤',
#   4: '<a href="https://www.youtube.com/watch?v=Ks-_Mh1QhMc&amp;t=7m09s">7:09</a> <a href="https://www.youtube.com/watch?v=Ks-_Mh1QhMc&amp;t=15m09s">15:09</a> <a href="https://www.youtube.com/watch?v=Ks-_Mh1QhMc&amp;t=15m53s">15:53</a> <a href="https://www.youtube.com/watch?v=Ks-_Mh1QhMc&amp;t=16m13s">16:13</a>',
#   5: 'This makes me tear and get emotional',
#   6: 'its nice seeing that things I thought of in my head as true are scientifically proven to bde true',
# ...
